# %%
#IMPORT THE LIBRARIES
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
import IPython.display as ipd
from IPython.display import Audio
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD



import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import tensorflow as tf
print ("Done")
# Out:
# Done

# %%
# !apt-get update
# !apt-get install -y libsndfile1
# Out:
# Get:1 http://packages.cloud.google.com/apt gcsfuse-focal InRelease [1227 B]
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:4 https://packages.cloud.google.com/apt cloud-sdk InRelease [1618 B]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:6 https://packages.cloud.google.com/apt google-fast-socket InRelease [1071 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Get:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Err:1 http://packages.cloud.google.com/apt gcsfuse-focal InRelease
#   The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# Err:4 https://packages.cloud.google.com/apt cloud-sdk InRelease
#   The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# Err:6 https://packages.cloud.google.com/apt google-fast-socket InRelease
#   The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [2562 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [33.1 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [4396 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [36.8 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [4724 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1599 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1308 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [4921 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [4883 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [28.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [55.2 kB]
# Fetched 24.9 MB in 3s (9781 kB/s)
# Reading package lists... Done
# W: An error occurred during the signature verification. The repository is not updated and the previous index files will be used. GPG error: http://packages.cloud.google.com/apt gcsfuse-focal InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# W: An error occurred during the signature verification. The repository is not updated and the previous index files will be used. GPG error: https://packages.cloud.google.com/apt cloud-sdk InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# W: An error occurred during the signature verification. The repository is not updated and the previous index files will be used. GPG error: https://packages.cloud.google.com/apt google-fast-socket InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# W: Failed to fetch http://packages.cloud.google.com/apt/dists/gcsfuse-focal/InRelease  The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# W: Failed to fetch https://packages.cloud.google.com/apt/dists/cloud-sdk/InRelease  The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# W: Failed to fetch https://packages.cloud.google.com/apt/dists/google-fast-socket/InRelease  The following signatures couldn't be verified because the public key is not available: NO_PUBKEY C0BA5CE6DC6315A3
# W: Some index files failed to download. They have been ignored, or old ones used instead.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages will be upgraded:
#   libsndfile1
# 1 upgraded, 0 newly installed, 0 to remove and 248 not upgraded.
# Need to get 170 kB of archives.
# After this operation, 4096 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsndfile1 amd64 1.0.28-7ubuntu0.3 [170 kB]
# Fetched 170 kB in 0s (898 kB/s)
# (Reading database ... 108875 files and directories currently installed.)
# Preparing to unpack .../libsndfile1_1.0.28-7ubuntu0.3_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.28-7ubuntu0.3) over (1.0.28-7ubuntu0.1) ...
# Setting up libsndfile1:amd64 (1.0.28-7ubuntu0.3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.7) ...

# %% [markdown]
# # Importing Data

# %%
#preparing data set

ravdess = "/kaggle/input/ravdess-emotional-speech-audio/audio_speech_actors_01-24/"
ravdess_directory_list = os.listdir(ravdess)
print(ravdess_directory_list)
# Out:
# ['Actor_02', 'Actor_17', 'Actor_05', 'Actor_16', 'Actor_21', 'Actor_01', 'Actor_11', 'Actor_20', 'Actor_08', 'Actor_15', 'Actor_06', 'Actor_12', 'Actor_23', 'Actor_24', 'Actor_22', 'Actor_04', 'Actor_19', 'Actor_10', 'Actor_09', 'Actor_14', 'Actor_03', 'Actor_13', 'Actor_18', 'Actor_07']

# %%
Crema = "/kaggle/input/cremad/AudioWAV/"
Tess = "/kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/"

# %% [markdown]
# # preprocessing

# %% [markdown]
# **Ravdees**

# %%
file_emotion = []
file_path = []
for i in ravdess_directory_list:
    # as their are 24 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(ravdess + i)
    for f in actor:
        part = f.split('.')[0].split('-')
    # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(ravdess + i + '/' + f)

# %%
print(actor[0])
print(part[0])
print(file_path[0])
print(int(part[2]))
print(f)
# Out:
# 03-01-06-02-01-01-07.wav
# 03
# /kaggle/input/ravdess-emotional-speech-audio/audio_speech_actors_01-24/Actor_02/03-01-08-01-01-01-02.wav
# 5
# 03-01-05-02-01-02-07.wav

# %%
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
ravdess_df = pd.concat([emotion_df, path_df], axis=1)
# changing integers to actual emotions.
ravdess_df.Emotions.replace({1:'neutral', 2:'neutral', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust',
                             8:'surprise'},
                            inplace=True)
print(ravdess_df.head())
print("______________________________________________")
print(ravdess_df.tail())
print("_______________________________________________")
print(ravdess_df.Emotions.value_counts())
# Out:
#    Emotions                                               Path
# 0  surprise  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...
# 2   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 3   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 4   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...
# ______________________________________________
#      Emotions                                               Path
# 1435     fear  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1436    angry  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1437      sad  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1438  disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1439    angry  /kaggle/input/ravdess-emotional-speech-audio/a...
# _______________________________________________
# neutral     288
# surprise    192
# disgust     192
# fear        192
# sad         192
# happy       192
# angry       192
# Name: Emotions, dtype: int64

# %% [markdown]
# **Crema DataFrame**

# %%
crema_directory_list = os.listdir(Crema)

file_emotion = []
file_path = []

for file in crema_directory_list:
    # storing file paths
    file_path.append(Crema + file)
    # storing file emotions
    part=file.split('_')
    if part[2] == 'SAD':
        file_emotion.append('sad')
    elif part[2] == 'ANG':
        file_emotion.append('angry')
    elif part[2] == 'DIS':
        file_emotion.append('disgust')
    elif part[2] == 'FEA':
        file_emotion.append('fear')
    elif part[2] == 'HAP':
        file_emotion.append('happy')
    elif part[2] == 'NEU':
        file_emotion.append('neutral')
    else:
        file_emotion.append('Unknown')

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Crema_df = pd.concat([emotion_df, path_df], axis=1)
Crema_df.head()
print(Crema_df.Emotions.value_counts())
# Out:
# disgust    1271
# happy      1271
# sad        1271
# fear       1271
# angry      1271
# neutral    1087
# Name: Emotions, dtype: int64

# %% [markdown]
# **TESS dataset**

# %%
tess_directory_list = os.listdir(Tess)

file_emotion = []
file_path = []

for dir in tess_directory_list:
    directories = os.listdir(Tess + dir)
    for file in directories:
        part = file.split('.')[0]
        part = part.split('_')[2]
        if part=='ps':
            file_emotion.append('surprise')
        else:
            file_emotion.append(part)
        file_path.append(Tess + dir + '/' + file)

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
Tess_df.head()
print(Tess_df.Emotions.value_counts())
# Out:
# fear        400
# angry       400
# disgust     400
# neutral     400
# sad         400
# surprise    400
# happy       400
# Name: Emotions, dtype: int64

# %% [markdown]
# **SAVEE Dataset**

# %% [markdown]
# **Integration**

# %%
# creating Dataframe using all the 3 dataframes we created so far.
data_path = pd.concat([ravdess_df, Crema_df, Tess_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#    Emotions                                               Path
# 0  surprise  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...
# 2   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 3   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 4   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...

# %%
print(data_path.Emotions.value_counts())
# Out:
# disgust     1863
# fear        1863
# sad         1863
# happy       1863
# angry       1863
# neutral     1775
# surprise     592
# Name: Emotions, dtype: int64

# %% [markdown]
# >*                           Data Visualisation and Exploration

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.title('Count of Emotions', size=16)
sns.countplot(data_path.Emotions)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
data,sr = librosa.load(file_path[0])
sr
# Out:
# 22050

# %%
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
plt.figure(figsize=(10, 5))
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000)
log_spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(log_spectrogram, y_axis='mel', sr=sr, x_axis='time');
plt.title('Mel Spectrogram ')
plt.colorbar(format='%+2.0f dB')

# %%
mfcc = librosa.feature.mfcc(y=data, sr=sr, n_mfcc=30)


# MFCC
plt.figure(figsize=(16, 10))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc, x_axis='time')
plt.ylabel('MFCC')
plt.colorbar()

ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Data augmentation

# %%
# NOISE
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

# STRETCH
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)
# SHIFT
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)
# PITCH
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# %%
# NORMAL AUDIO


import librosa.display
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=data, sr=sr)
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# AUDIO WITH NOISE
x = noise(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# STRETCHED AUDIO
x = stretch(data)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# SHIFTED AUDIO
x = shift(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# AUDIO WITH PITCH
x = pitch(data, sr)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature extraction

# %%
def zcr(data,frame_length,hop_length):
    zcr=librosa.feature.zero_crossing_rate(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(zcr)
def rmse(data,frame_length=2048,hop_length=512):
    rmse=librosa.feature.rms(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(rmse)
def mfcc(data,sr,frame_length=2048,hop_length=512,flatten:bool=True):
    mfcc=librosa.feature.mfcc(data,sr=sr)
    return np.squeeze(mfcc.T)if not flatten else np.ravel(mfcc.T)

def extract_features(data,sr=22050,frame_length=2048,hop_length=512):
    result=np.array([])

    result=np.hstack((result,
                      zcr(data,frame_length,hop_length),
                      rmse(data,frame_length,hop_length),
                      mfcc(data,sr,frame_length,hop_length)
                     ))
    return result

def get_features(path,duration=2.5, offset=0.6):
    data,sr=librosa.load(path,duration=duration,offset=offset)
    aud=extract_features(data)
    audio=np.array(aud)

    noised_audio=noise(data)
    aud2=extract_features(noised_audio)
    audio=np.vstack((audio,aud2))

    pitched_audio=pitch(data,sr)
    aud3=extract_features(pitched_audio)
    audio=np.vstack((audio,aud3))

    pitched_audio1=pitch(data,sr)
    pitched_noised_audio=noise(pitched_audio1)
    aud4=extract_features(pitched_noised_audio)
    audio=np.vstack((audio,aud4))

    return audio

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  4

# %% [markdown]
# # Noraml way to get features

# %%
import timeit
from tqdm import tqdm
start = timeit.default_timer()
X,Y=[],[]
for path,emotion,index in tqdm (zip(data_path.Path,data_path.Emotions,range(data_path.Path.shape[0]))):
    features=get_features(path)
    if index%500==0:
        print(f'{index} audio has been processed')
    for i in features:
        X.append(i)
        Y.append(emotion)
print('Done')
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# 1it [00:00,  2.10it/s]
# 0 audio has been processed
# 501it [04:39,  1.79it/s]
# 500 audio has been processed
# 1001it [09:15,  1.82it/s]
# 1000 audio has been processed
# 1501it [13:44,  2.20it/s]
# 1500 audio has been processed
# 2001it [17:19,  2.45it/s]
# 2000 audio has been processed
# 2501it [20:58,  2.15it/s]
# 2500 audio has been processed
# 3001it [24:34,  2.17it/s]
# 3000 audio has been processed
# 3501it [28:08,  2.30it/s]
# 3500 audio has been processed
# 4001it [31:45,  2.34it/s]
# 4000 audio has been processed
# 4501it [35:20,  2.46it/s]
# 4500 audio has been processed
# 5001it [38:57,  2.36it/s]
# 5000 audio has been processed
# 5501it [42:34,  2.38it/s]
# 5500 audio has been processed
# 6001it [46:09,  2.20it/s]
# 6000 audio has been processed
# 6501it [49:48,  2.23it/s]
# 6500 audio has been processed
# 7001it [53:26,  2.33it/s]
# 7000 audio has been processed
# 7501it [57:03,  2.37it/s]
# 7500 audio has been processed
# 8001it [1:00:39,  2.39it/s]
# 8000 audio has been processed
# 8501it [1:04:17,  2.20it/s]
# 8500 audio has been processed
# 9001it [1:07:43,  2.79it/s]
# 9000 audio has been processed
# 9501it [1:10:26,  2.36it/s]
# 9500 audio has been processed
# 10001it [1:13:56,  2.46it/s]
# 10000 audio has been processed
# 10501it [1:17:42,  2.49it/s]
# 10500 audio has been processed
# 11001it [1:21:04,  2.46it/s]
# 11000 audio has been processed
# 11501it [1:24:28,  2.78it/s]
# 11500 audio has been processed
# 11682it [1:25:37,  2.27it/s]
# Done
# Time:  5137.607935512

# %%
len(X), len(Y), data_path.Path.shape
# Out:
# (46728, 46728, (11682,))

# %% [markdown]
# # Saving features

# %%
Emotions = pd.DataFrame(X)
Emotions['Emotions'] = Y
Emotions.to_csv('emotion.csv', index=False)
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.331543  0.471680  0.564941  0.452148  0.374512  0.296875  0.265137
# 1  0.252441  0.377441  0.498535  0.495117  0.494141  0.494141  0.494629
# 2  0.299805  0.419922  0.525879  0.459473  0.378418  0.326172  0.282227
# 3  0.251953  0.375488  0.511230  0.505371  0.518555  0.533203  0.519531
# 4  0.400879  0.591309  0.783203  0.777832  0.771973  0.777832  0.771973
#
#           7         8         9  ...      2367       2368      2369      2370  \
# 0  0.256348  0.252441  0.251953  ... -1.517647  -1.716411 -1.599245 -1.234544
# 1  0.488281  0.487305  0.479004  ...  5.865515  10.963460  6.186625  2.542382
# 2  0.260254  0.258789  0.253906  ...  0.518931   0.839123  1.308965  1.855116
# 3  0.520996  0.509277  0.497070  ...  0.066455   3.359560  1.369975 -2.367700
# 4  0.775391  0.758789  0.580078  ...  2.585884   2.746578  2.223155  0.986784
#
#        2371      2372      2373      2374      2375  Emotions
# 0 -0.693115 -0.038821  0.675410  1.405862  2.112551  surprise
# 1 -2.396881  0.287381  3.624207  8.807546  4.917188  surprise
# 2  2.404975  2.896071  3.282977  3.541091  3.666846  surprise
# 3 -3.973268  4.332744  4.200258  3.298345  3.115802  surprise
# 4 -0.730886 -2.531058 -4.002848 -4.849192 -4.929412   neutral
#
# [5 rows x 2377 columns]

# %%
Emotions = pd.read_csv('./emotion.csv')
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.331543  0.471680  0.564941  0.452148  0.374512  0.296875  0.265137
# 1  0.252441  0.377441  0.498535  0.495117  0.494141  0.494141  0.494629
# 2  0.299805  0.419922  0.525879  0.459473  0.378418  0.326172  0.282227
# 3  0.251953  0.375488  0.511230  0.505371  0.518555  0.533203  0.519531
# 4  0.400879  0.591309  0.783203  0.777832  0.771973  0.777832  0.771973
#
#           7         8         9  ...      2367       2368      2369      2370  \
# 0  0.256348  0.252441  0.251953  ... -1.517647  -1.716411 -1.599245 -1.234544
# 1  0.488281  0.487305  0.479004  ...  5.865515  10.963460  6.186625  2.542382
# 2  0.260254  0.258789  0.253906  ...  0.518931   0.839123  1.308965  1.855116
# 3  0.520996  0.509277  0.497070  ...  0.066455   3.359560  1.369975 -2.367700
# 4  0.775391  0.758789  0.580078  ...  2.585884   2.746578  2.223155  0.986784
#
#        2371      2372      2373      2374      2375  Emotions
# 0 -0.693115 -0.038821  0.675410  1.405862  2.112551  surprise
# 1 -2.396881  0.287381  3.624207  8.807546  4.917188  surprise
# 2  2.404975  2.896071  3.282977  3.541091  3.666846  surprise
# 3 -3.973268  4.332744  4.200258  3.298345  3.115802  surprise
# 4 -0.730886 -2.531058 -4.002848 -4.849192 -4.929412   neutral
#
# [5 rows x 2377 columns]

# %%
print(Emotions.isna().any())
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372         True
# 2373         True
# 2374         True
# 2375         True
# Emotions    False
# Length: 2377, dtype: bool

# %%
Emotions=Emotions.fillna(0)
print(Emotions.isna().any())
Emotions.shape
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372        False
# 2373        False
# 2374        False
# 2375        False
# Emotions    False
# Length: 2377, dtype: bool
# (46728, 2377)

# %%
np.sum(Emotions.isna())
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 2372        0
# 2373        0
# 2374        0
# 2375        0
# Emotions    0
# Length: 2377, dtype: int64

# %% [markdown]
# # Data preparation

# %%
#taking all rows and all cols without last col for X which include features
#taking last col for Y, which include the emotions


X = Emotions.iloc[: ,:-1].values
Y = Emotions['Emotions'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y
from sklearn.preprocessing import StandardScaler, OneHotEncoder
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
print(Y.shape)
X.shape
# Out:
# (46728, 7)
# (46728, 2376)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=42,test_size=0.2, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((37382, 2376), (37382, 7), (9346, 2376), (9346, 7))

# %%
#reshape for lstm
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((37382, 2376), (37382, 7), (9346, 2376), (9346, 7))

# %%
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# > Applying early stopping for all models

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
model_checkpoint = ModelCheckpoint('best_model1_weights.h5', monitor='val_accuracy', save_best_only=True)

# %%
early_stop=EarlyStopping(monitor='val_acc',mode='auto',patience=5,restore_best_weights=True)
lr_reduction=ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.5,min_lr=0.00001)

# %%
#Reshape for CNN_LSTM MODEL

x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
#x_testcnn[0]
# Out:
# ((37382, 2376, 1), (37382, 7), (9346, 2376, 1), (9346, 7))

# %%
#Build the model

# define model
model000 = Sequential()
model000.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(X.shape[1], 1)))
model000.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model000.add(BatchNormalization())
model000.add(Dropout(0.3))


model000.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model000.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model000.add(BatchNormalization())
model000.add(Dropout(0.3))

model000.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model000.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model000.add(BatchNormalization())
model000.add(Dropout(0.3))

model000.add(LSTM(128, return_sequences=True))
model000.add(Dropout(0.3))

model000.add(LSTM(128, return_sequences=True))
model000.add(Dropout(0.3))
model000.add(LSTM(128))
model000.add(Dropout(0.3))

model000.add(Dense(128, activation='relu'))
#model000.add(Dropout(0.3))

model000.add(Dense(64, activation='relu'))
#model000.add(Dropout(0.3))

model000.add(Dense(32, activation='relu'))
#model000.add(Dropout(0.3))

model000.add(Dense(7, activation='softmax'))



model000.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 2376, 1024)        6144
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1188, 1024)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1188, 1024)        4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1188, 1024)        0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1188, 512)         2621952
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 594, 512)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 594, 512)          2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 594, 512)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 594, 256)          655616
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 297, 256)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 297, 256)          1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 297, 256)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 297, 128)          197120
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 297, 128)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 297, 128)          131584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 297, 128)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 3,778,247
# Trainable params: 3,774,663
# Non-trainable params: 3,584
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model( model000, show_shapes=True, show_layer_names=True, to_file='model000.png')

# %%
model000.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist1=model000.fit(x_traincnn, y_train, batch_size=64, epochs=100, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/100
# 585/585 [==============================] - 331s 537ms/step - loss: 1.8612 - accuracy: 0.2132 - val_loss: 1.8955 - val_accuracy: 0.2016
# Epoch 2/100
# 585/585 [==============================] - 322s 550ms/step - loss: 1.8007 - accuracy: 0.2416 - val_loss: 1.7525 - val_accuracy: 0.2572
# Epoch 3/100
# 585/585 [==============================] - 316s 541ms/step - loss: 1.6882 - accuracy: 0.3076 - val_loss: 1.6493 - val_accuracy: 0.3340
# Epoch 4/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.6147 - accuracy: 0.3502 - val_loss: 1.5400 - val_accuracy: 0.3857
# Epoch 5/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.5439 - accuracy: 0.3786 - val_loss: 1.5273 - val_accuracy: 0.3753
# Epoch 6/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.4542 - accuracy: 0.4099 - val_loss: 1.4004 - val_accuracy: 0.4334
# Epoch 7/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.5317 - accuracy: 0.3788 - val_loss: 1.5022 - val_accuracy: 0.4018
# Epoch 8/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.3948 - accuracy: 0.4356 - val_loss: 1.3415 - val_accuracy: 0.4669
# Epoch 9/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.3338 - accuracy: 0.4642 - val_loss: 1.2912 - val_accuracy: 0.4920
# Epoch 10/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.2935 - accuracy: 0.4842 - val_loss: 1.2681 - val_accuracy: 0.4924
# Epoch 11/100
# 585/585 [==============================] - 321s 549ms/step - loss: 1.2679 - accuracy: 0.4949 - val_loss: 1.2524 - val_accuracy: 0.5010
# Epoch 12/100
# 585/585 [==============================] - 323s 552ms/step - loss: 1.2400 - accuracy: 0.5069 - val_loss: 1.2034 - val_accuracy: 0.5215
# Epoch 13/100
# 585/585 [==============================] - 323s 552ms/step - loss: 1.2179 - accuracy: 0.5159 - val_loss: 1.2236 - val_accuracy: 0.5182
# Epoch 14/100
# 585/585 [==============================] - 319s 545ms/step - loss: 1.1955 - accuracy: 0.5249 - val_loss: 1.1720 - val_accuracy: 0.5378
# Epoch 15/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.1773 - accuracy: 0.5326 - val_loss: 1.1460 - val_accuracy: 0.5479
# Epoch 16/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.1713 - accuracy: 0.5349 - val_loss: 1.1603 - val_accuracy: 0.5388
# Epoch 17/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.1612 - accuracy: 0.5408 - val_loss: 1.1941 - val_accuracy: 0.5286
# Epoch 18/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.1391 - accuracy: 0.5467 - val_loss: 1.1311 - val_accuracy: 0.5569
# Epoch 19/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.1309 - accuracy: 0.5531 - val_loss: 1.1106 - val_accuracy: 0.5523
# Epoch 20/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.1096 - accuracy: 0.5612 - val_loss: 1.0894 - val_accuracy: 0.5658
# Epoch 21/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.0919 - accuracy: 0.5677 - val_loss: 1.0984 - val_accuracy: 0.5722
# Epoch 22/100
# 585/585 [==============================] - 318s 543ms/step - loss: 1.0792 - accuracy: 0.5749 - val_loss: 1.0675 - val_accuracy: 0.5827
# Epoch 23/100
# 585/585 [==============================] - 323s 552ms/step - loss: 1.0667 - accuracy: 0.5797 - val_loss: 1.0648 - val_accuracy: 0.5775
# Epoch 24/100
# 585/585 [==============================] - 323s 552ms/step - loss: 1.0506 - accuracy: 0.5864 - val_loss: 1.0627 - val_accuracy: 0.5827
# Epoch 25/100
# 585/585 [==============================] - 320s 548ms/step - loss: 1.0291 - accuracy: 0.5955 - val_loss: 1.0206 - val_accuracy: 0.5985
# Epoch 26/100
# 585/585 [==============================] - 315s 539ms/step - loss: 1.0163 - accuracy: 0.6042 - val_loss: 1.0416 - val_accuracy: 0.5860
# Epoch 27/100
# 585/585 [==============================] - 315s 539ms/step - loss: 0.9993 - accuracy: 0.6132 - val_loss: 1.0596 - val_accuracy: 0.5868
# Epoch 28/100
# 585/585 [==============================] - 315s 539ms/step - loss: 0.9757 - accuracy: 0.6197 - val_loss: 0.9871 - val_accuracy: 0.6115
# Epoch 29/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.9502 - accuracy: 0.6315 - val_loss: 0.9889 - val_accuracy: 0.6180
# Epoch 30/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.9365 - accuracy: 0.6361 - val_loss: 0.9777 - val_accuracy: 0.6233
# Epoch 31/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.9254 - accuracy: 0.6416 - val_loss: 0.9420 - val_accuracy: 0.6349
# Epoch 32/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.9049 - accuracy: 0.6501 - val_loss: 0.9770 - val_accuracy: 0.6247
# Epoch 33/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.8899 - accuracy: 0.6573 - val_loss: 1.0284 - val_accuracy: 0.5963
# Epoch 34/100
# 585/585 [==============================] - 323s 552ms/step - loss: 0.8916 - accuracy: 0.6549 - val_loss: 0.9249 - val_accuracy: 0.6422
# Epoch 35/100
# 585/585 [==============================] - 323s 552ms/step - loss: 0.8684 - accuracy: 0.6656 - val_loss: 0.9415 - val_accuracy: 0.6372
# Epoch 36/100
# 585/585 [==============================] - 323s 552ms/step - loss: 0.8520 - accuracy: 0.6721 - val_loss: 0.9209 - val_accuracy: 0.6442
# Epoch 37/100
# 585/585 [==============================] - 316s 540ms/step - loss: 0.8512 - accuracy: 0.6750 - val_loss: 0.8872 - val_accuracy: 0.6623
# Epoch 38/100
# 585/585 [==============================] - 315s 539ms/step - loss: 0.8237 - accuracy: 0.6862 - val_loss: 0.9329 - val_accuracy: 0.6496
# Epoch 39/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.8053 - accuracy: 0.6915 - val_loss: 0.8778 - val_accuracy: 0.6605
# Epoch 40/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.7962 - accuracy: 0.6943 - val_loss: 0.8941 - val_accuracy: 0.6625
# Epoch 41/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.7908 - accuracy: 0.6985 - val_loss: 0.8605 - val_accuracy: 0.6774
# Epoch 42/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.7740 - accuracy: 0.7054 - val_loss: 0.8759 - val_accuracy: 0.6730
# Epoch 43/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.7613 - accuracy: 0.7121 - val_loss: 0.8562 - val_accuracy: 0.6789
# Epoch 44/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.7522 - accuracy: 0.7138 - val_loss: 0.9227 - val_accuracy: 0.6548
# Epoch 45/100
# 585/585 [==============================] - 321s 549ms/step - loss: 0.7374 - accuracy: 0.7218 - val_loss: 0.8729 - val_accuracy: 0.6756
# Epoch 46/100
# 585/585 [==============================] - 323s 552ms/step - loss: 0.7285 - accuracy: 0.7243 - val_loss: 0.8313 - val_accuracy: 0.6868
# Epoch 47/100
# 585/585 [==============================] - 323s 552ms/step - loss: 0.7131 - accuracy: 0.7302 - val_loss: 0.8165 - val_accuracy: 0.6938
# Epoch 48/100
# 585/585 [==============================] - 319s 545ms/step - loss: 0.7128 - accuracy: 0.7288 - val_loss: 0.8108 - val_accuracy: 0.6976
# Epoch 49/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.6921 - accuracy: 0.7394 - val_loss: 0.8640 - val_accuracy: 0.6761
# Epoch 50/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.6933 - accuracy: 0.7401 - val_loss: 0.8056 - val_accuracy: 0.7030
# Epoch 51/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.6746 - accuracy: 0.7472 - val_loss: 0.7952 - val_accuracy: 0.7034
# Epoch 52/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.6526 - accuracy: 0.7550 - val_loss: 0.8146 - val_accuracy: 0.7043
# Epoch 53/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.6440 - accuracy: 0.7576 - val_loss: 0.8105 - val_accuracy: 0.7095
# Epoch 54/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.6474 - accuracy: 0.7596 - val_loss: 0.7815 - val_accuracy: 0.7090
# Epoch 55/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.6280 - accuracy: 0.7646 - val_loss: 0.7615 - val_accuracy: 0.7190
# Epoch 56/100
# 585/585 [==============================] - 319s 545ms/step - loss: 0.6285 - accuracy: 0.7664 - val_loss: 0.7339 - val_accuracy: 0.7294
# Epoch 57/100
# 585/585 [==============================] - 322s 551ms/step - loss: 0.6103 - accuracy: 0.7719 - val_loss: 0.7556 - val_accuracy: 0.7228
# Epoch 58/100
# 585/585 [==============================] - 323s 551ms/step - loss: 0.5983 - accuracy: 0.7774 - val_loss: 0.7671 - val_accuracy: 0.7205
# Epoch 59/100
# 585/585 [==============================] - 321s 548ms/step - loss: 0.5954 - accuracy: 0.7791 - val_loss: 0.7636 - val_accuracy: 0.7238
# Epoch 60/100
# 585/585 [==============================] - 316s 540ms/step - loss: 0.5776 - accuracy: 0.7862 - val_loss: 0.7821 - val_accuracy: 0.7206
# Epoch 61/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.5714 - accuracy: 0.7869 - val_loss: 0.7424 - val_accuracy: 0.7345
# Epoch 62/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.5651 - accuracy: 0.7885 - val_loss: 0.7334 - val_accuracy: 0.7281
# Epoch 63/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.5544 - accuracy: 0.7946 - val_loss: 0.7168 - val_accuracy: 0.7436
# Epoch 64/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.5477 - accuracy: 0.7960 - val_loss: 0.7527 - val_accuracy: 0.7284
# Epoch 65/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.5207 - accuracy: 0.8075 - val_loss: 0.7516 - val_accuracy: 0.7372
# Epoch 66/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.5298 - accuracy: 0.8053 - val_loss: 0.7272 - val_accuracy: 0.7426
# Epoch 67/100
# 585/585 [==============================] - 316s 540ms/step - loss: 0.5165 - accuracy: 0.8085 - val_loss: 0.6934 - val_accuracy: 0.7468
# Epoch 68/100
# 585/585 [==============================] - 322s 551ms/step - loss: 0.5047 - accuracy: 0.8130 - val_loss: 0.6844 - val_accuracy: 0.7570
# Epoch 69/100
# 585/585 [==============================] - 322s 551ms/step - loss: 0.4937 - accuracy: 0.8182 - val_loss: 0.7456 - val_accuracy: 0.7457
# Epoch 70/100
# 585/585 [==============================] - 322s 551ms/step - loss: 0.4862 - accuracy: 0.8217 - val_loss: 0.7132 - val_accuracy: 0.7481
# Epoch 71/100
# 585/585 [==============================] - 316s 541ms/step - loss: 0.4800 - accuracy: 0.8233 - val_loss: 0.6597 - val_accuracy: 0.7707
# Epoch 72/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.4783 - accuracy: 0.8262 - val_loss: 0.7337 - val_accuracy: 0.7387
# Epoch 73/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.4656 - accuracy: 0.8297 - val_loss: 0.6556 - val_accuracy: 0.7695
# Epoch 74/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.4659 - accuracy: 0.8310 - val_loss: 0.7164 - val_accuracy: 0.7549
# Epoch 75/100
# 585/585 [==============================] - 314s 538ms/step - loss: 0.4472 - accuracy: 0.8390 - val_loss: 0.6668 - val_accuracy: 0.7647
# Epoch 76/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.4333 - accuracy: 0.8423 - val_loss: 0.6711 - val_accuracy: 0.7691
# Epoch 77/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.4327 - accuracy: 0.8439 - val_loss: 0.6941 - val_accuracy: 0.7628
# Epoch 78/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.4282 - accuracy: 0.8435 - val_loss: 0.6911 - val_accuracy: 0.7637
# Epoch 79/100
# 585/585 [==============================] - 321s 549ms/step - loss: 0.4251 - accuracy: 0.8460 - val_loss: 0.6653 - val_accuracy: 0.7765
# Epoch 80/100
# 585/585 [==============================] - 322s 551ms/step - loss: 0.4100 - accuracy: 0.8519 - val_loss: 0.7022 - val_accuracy: 0.7624
# Epoch 81/100
# 585/585 [==============================] - 322s 551ms/step - loss: 0.4014 - accuracy: 0.8566 - val_loss: 0.6746 - val_accuracy: 0.7731
# Epoch 82/100
# 585/585 [==============================] - 319s 545ms/step - loss: 0.3960 - accuracy: 0.8565 - val_loss: 0.6459 - val_accuracy: 0.7794
# Epoch 83/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.3941 - accuracy: 0.8579 - val_loss: 0.6628 - val_accuracy: 0.7825
# Epoch 84/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.3964 - accuracy: 0.8587 - val_loss: 0.6644 - val_accuracy: 0.7801
# Epoch 85/100
# 585/585 [==============================] - 314s 538ms/step - loss: 0.3809 - accuracy: 0.8638 - val_loss: 0.6316 - val_accuracy: 0.7839
# Epoch 86/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.3739 - accuracy: 0.8643 - val_loss: 0.6223 - val_accuracy: 0.7873
# Epoch 87/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.3766 - accuracy: 0.8654 - val_loss: 0.6432 - val_accuracy: 0.7845
# 585/585 [==============================] - 314s 537ms/step - loss: 0.3520 - accuracy: 0.8735 - val_loss: 0.6066 - val_accuracy: 0.7949
# Epoch 89/100
# 585/585 [==============================] - 314s 538ms/step - loss: 0.3516 - accuracy: 0.8745 - val_loss: 0.6267 - val_accuracy: 0.7931
# Epoch 90/100
# 585/585 [==============================] - 318s 544ms/step - loss: 0.3487 - accuracy: 0.8773 - val_loss: 0.6293 - val_accuracy: 0.7856
# Epoch 91/100
# 585/585 [==============================] - 323s 551ms/step - loss: 0.3463 - accuracy: 0.8766 - val_loss: 0.5879 - val_accuracy: 0.8001
# 585/585 [==============================] - 323s 552ms/step - loss: 0.3452 - accuracy: 0.8784 - val_loss: 0.6203 - val_accuracy: 0.8011
# Epoch 93/100
# 585/585 [==============================] - 321s 549ms/step - loss: 0.3336 - accuracy: 0.8810 - val_loss: 0.6129 - val_accuracy: 0.7966
# Epoch 94/100
# 585/585 [==============================] - 315s 539ms/step - loss: 0.3286 - accuracy: 0.8827 - val_loss: 0.6110 - val_accuracy: 0.8049
# Epoch 95/100
# 585/585 [==============================] - 315s 538ms/step - loss: 0.3214 - accuracy: 0.8875 - val_loss: 0.5812 - val_accuracy: 0.8064
# Epoch 96/100
# 585/585 [==============================] - 314s 538ms/step - loss: 0.3230 - accuracy: 0.8850 - val_loss: 0.6111 - val_accuracy: 0.8091
# Epoch 97/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.3141 - accuracy: 0.8882 - val_loss: 0.6621 - val_accuracy: 0.7923
# Epoch 98/100
# 585/585 [==============================] - 314s 537ms/step - loss: 0.3193 - accuracy: 0.8879 - val_loss: 0.5712 - val_accuracy: 0.8097
# Epoch 99/100
# 585/585 [==============================] - 314s 538ms/step - loss: 0.2992 - accuracy: 0.8947 - val_loss: 0.5815 - val_accuracy: 0.8083
# Epoch 100/100
# 585/585 [==============================] - 314s 538ms/step - loss: 0.2957 - accuracy: 0.8950 - val_loss: 0.5827 - val_accuracy: 0.8115

# %%
print("Accuracy of our model on test data : " , model000.evaluate(x_testcnn,y_test)[1]*100 , "%")
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = hist1.history['accuracy']
train_loss = hist1.history['loss']
test_acc = hist1.history['val_accuracy']
test_loss = hist1.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 293/293 [==============================] - 26s 86ms/step - loss: 0.5827 - accuracy: 0.8115
# Accuracy of our model on test data :  81.14701509475708 %

# %%
# predicting on test data.
pred_test00 = model000.predict(x_testcnn)
y_pred00 = encoder.inverse_transform(pred_test00)
y_test00 = encoder.inverse_transform(y_test)

# Check for random predictions
df0 = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df0['Predicted Labels'] = y_pred00.flatten()
df0['Actual Labels'] = y_test00.flatten()

df0.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0          neutral       neutral
# 1             fear       disgust
# 2              sad       disgust
# 3          neutral       neutral
# 4             fear          fear
# 5          disgust          fear
# 6             fear          fear
# 7          disgust         happy
# 8             fear          fear
# 9              sad       disgust

# %%
# predicting on test data.
pred_test0 = model000.predict(x_testcnn)
y_pred0 = encoder.inverse_transform(pred_test0)
y_test0 = encoder.inverse_transform(y_test)

# Check for random predictions
df0 = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df0['Predicted Labels'] = y_pred0.flatten()
df0['Actual Labels'] = y_test0.flatten()

df0.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0          neutral       neutral
# 1             fear       disgust
# 2              sad       disgust
# 3          neutral       neutral
# 4             fear          fear
# 5          disgust          fear
# 6             fear          fear
# 7          disgust         happy
# 8             fear          fear
# 9              sad       disgust

# %% [markdown]
# # Evalutation

# %% [markdown]
# Results of best model

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test00, y_pred00)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
#cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='.2f')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
print(classification_report(y_test0, y_pred0))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.84      0.89      0.87      1483
#      disgust       0.74      0.80      0.77      1513
#         fear       0.85      0.69      0.77      1451
#        happy       0.82      0.77      0.79      1464
#      neutral       0.83      0.85      0.84      1475
#          sad       0.76      0.82      0.79      1491
#     surprise       0.96      0.94      0.95       469
#
#     accuracy                           0.81      9346
#    macro avg       0.83      0.82      0.82      9346
# weighted avg       0.81      0.81      0.81      9346
